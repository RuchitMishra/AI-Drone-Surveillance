# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 61.8 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
import os

drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# /tmp/ipykernel_2315/3775937972.py in <cell line: 0>()
#       3
#       4 # Mount Drive
# ----> 5 drive.mount('/content/drive')
#       6
#       7 # Install Ultralytics for YOLO11
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     132   )
#     133   if ephemeral:
# --> 134     _message.blocking_request(
#     135         'request_auth',
# ...

# %%
zip_path = '/content/drive/MyDrive/path/to/archive (2).zip'
extract_path = '/content/drive/MyDrive/yolo_dataset/'


if not os.path.exists(extract_path):
    os.makedirs(extract_path)
    # !unzip -q "{zip_path}" -d "{extract_path}"
    print("Unzip complete.")
else:
    print("Dataset already unzipped in Drive.")

# %%
from ultralytics import YOLO


project_path = '/content/drive/MyDrive/yolo_training_results'


checkpoint = f"{project_path}/train_run/weights/last.pt"

if os.path.exists(checkpoint):
    print("Resuming from checkpoint...")
    model = YOLO(checkpoint)
    model.train(resume=True)
else:
    print("Starting new training...")
    model = YOLO('yolo11n.pt')
    model.train(
        data='/content/drive/MyDrive/yolo_dataset/data.yaml',
        epochs=100,
        imgsz=640,
        project=project_path,
        name='train_run'
    )
